# %% [markdown]
# <a href="https://colab.research.google.com/github/Seokki-Kwon/Chatpter3test/blob/main/chapter3test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **a는 수강 학점이고 수강학점을 출력하는 코드**

# %%
a - 10
print(a)
# Out:
# 10
